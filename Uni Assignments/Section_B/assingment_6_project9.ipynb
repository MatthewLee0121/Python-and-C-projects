# %% [markdown]
# Project 9: Numerical Approximation of Derivatives (Finite Difference Method)
#
# Objective:
#
# Approximate the derivative of a function at a given point using Python.
#
# Instructions:
#
# 1. Write a Python function derivative(f, x) that approximates the
# derivative of a function f at a given point x using the finite
# difference method:
#
# 𝑓′(𝑥)≅(𝑓(𝑥 + ℎ ) - 𝑓(𝑥)) / ℎ
#
# where h is a small step size (e.g., h=0.0001).
#
# 2. Test the function with simple mathematical functions such as 𝑓(𝑥) =
# 𝑥2 and 𝑓(𝑥) = sin(𝑥), and compare the numerical results with the
# exact derivatives.
#
# 3. Extension:
#
# Modify the function to use the centred difference method for more
# accurate results:
#
# 𝑓′(𝑥)≅(𝑓(𝑥 + ℎ ) - 𝑓(𝑥 - h)) / 2ℎ

# %% [markdown]
# Lets first just define the function and add some comments

# %%
def derivative(f, x):
    #f = function x = the point we are interested in
    # will need to ask for a function to input
    #will then need to parse this string and translate it to pythonic syntax, then we can use eval
    #will then use the eval function to get derivative
    return 0

# %% [markdown]
# Okay lets now make a second function for the inputs we need and to parse over the string, I may need a few functions for this.

# %%
def derivative(f, x):
    #f = function x = the point we are interested in
    # will need to ask for a function to input
    #will then need to parse this string and translate it to pythonic syntax, then we can use eval
    #will then use the eval function to get derivative
    return 0

def getUserInputs():
    return func

# %% [markdown]
# im going to work more on getUserInputs this will be a little complex to write, so im going to write it then explain after maybe using a docustring

# %%
import math


def derivative(f, x):
    #f = function x = the point we are interested in
    # will need to ask for a function to input
    #will then need to parse this string and translate it to pythonic syntax, then we can use eval
    #will then use the eval function to get derivative
    return 0

def getUserInputsAndParse():
    #func = input("What is the function? (E.g x^2 + 5x + 4)")
    x = 0
    func = "x^2 + 5x + 4"

    print(func)
    math_functions = {
        "sin": "math.sin",
        "cos": "math.cos",
        "tan": "math.tan",
        "log": "math.log",
        "exp": "math.exp",
        "sqrt": "math.sqrt",
        "pi": "math.pi",
        "e": "math.e",
        "^": "**"
    }

    for original, replacement in math_functions.items():
        func = func.replace(original, replacement)
        print(func)
     
    print(func)
    print(eval(func))

getUserInputsAndParse()

# %% [markdown]
# I have commented out the input and just given a value for bug testing purposes for the testing i will use x^2 + 5x + 4 untill i have completed the derivative function then i will also test some trig functions within the equation

# %% [markdown]
# now I need to work on coefficients of x so 5x will turn into (5 * x) I will use the re.sub function. so I will need to import re
# func = sub(r'(\d)(x)', r'(\1 * \2)', func)
# used r for a raw string because otherwise I will get a bug when i declare \d and \1 \1
#
# pattern:
#
#     \d states for a digit
#     'x' is the string version for x
#     basically when the code detects a digit then a 'x' as this is the pattern i want to change
#
# replace(repl):
#
#     takes the pattern so 5x and takes the 5 (\1) and the x (\2) and changes it to be (5 * 1) so (\1 * \2)
#
# final part passes the function

# %%
import math
from re import sub

def derivative(f, x):
    #f = function x = the point we are interested in
    # will need to ask for a function to input
    #will then need to parse this string and translate it to pythonic syntax, then we can use eval
    #will then use the eval function to get derivative
    return 0

def getUserInputsAndParse():
    #func = input("What is the function? (E.g x^2 + 5x + 4)")
    x = 0
    func = "x^2 + 5x + 4"

    print(func)
    math_functions = {
        "sin": "math.sin",
        "cos": "math.cos",
        "tan": "math.tan",
        "log": "math.log",
        "exp": "math.exp",
        "sqrt": "math.sqrt",
        "pi": "math.pi",
        "e": "math.e",
        "^": "**"
    }

    for original, replacement in math_functions.items():
        func = func.replace(original, replacement)
        print(func)

    func = sub(r'(\d)(x)', r'(\1 * \2)', func)
     
    print(func)
    print(eval(func))

getUserInputsAndParse()

# %% [markdown]
# Now we can work on the derivative, this should be pretty easy as we can return it all in one line

# %%
import math
from re import sub

def derivative(f, x, h=0.001):
    #f = function x = the point we are interested in
    # will need to ask for a function to input
    #will then need to parse this string and translate it to pythonic syntax, then we can use eval
    #will then use the eval function to get derivative
    return (f(x + h) - f(x)) / (h)

def getUserInputsAndParse():
    #func = input("What is the function? (E.g x^2 + 5x + 4)")
    x = 0
    func = "x^2 + 5x + 4"

    print(func)
    math_functions = {
        "sin": "math.sin",
        "cos": "math.cos",
        "tan": "math.tan",
        "log": "math.log",
        "exp": "math.exp",
        "sqrt": "math.sqrt",
        "pi": "math.pi",
        "e": "math.e",
        "^": "**"
    }

    for original, replacement in math_functions.items():
        func = func.replace(original, replacement)
        print(func)

    func = sub(r'(\d)(x)', r'(\1 * \2)', func)
     
    print(func)
    print(eval(func))

    return func, x

func, x = getUserInputsAndParse()
derivative(func, x)

# %% [markdown]
# TypeError: 'str' object is not callable in the return (f(x + h) - f(x)) / (h) lets add a print(type()) call after we return it for debugging.

# %%
import math
from re import sub

def derivative(f, x, h=0.001):
    #f = function x = the point we are interested in
    # will need to ask for a function to input
    #will then need to parse this string and translate it to pythonic syntax, then we can use eval
    #will then use the eval function to get derivative
    return (f(x + h) - f(x)) / (h)

def getUserInputsAndParse():
    #func = input("What is the function? (E.g x^2 + 5x + 4)")
    x = 0
    func = "x^2 + 5x + 4"

    print(func)
    math_functions = {
        "sin": "math.sin",
        "cos": "math.cos",
        "tan": "math.tan",
        "log": "math.log",
        "exp": "math.exp",
        "sqrt": "math.sqrt",
        "pi": "math.pi",
        "e": "math.e",
        "^": "**"
    }

    for original, replacement in math_functions.items():
        func = func.replace(original, replacement)
        print(func)

    func = sub(r'(\d)(x)', r'(\1 * \2)', func)
     
    print(func)
    print(eval(func))

    return func, x

func, x = getUserInputsAndParse()
print(type(func))
derivative(func, x)

# %% [markdown]
# Okay so the issue is I am passing a string to the return line as f(x+h) however when f is a string I am getting a type error, this means I need to change what func is while I return it from getUserInputsAndParse. we can do this with lambda function

# %%
import math
from re import sub

def derivative(f, x, h=0.001):
    #f = function x = the point we are interested in
    # will need to ask for a function to input
    #will then need to parse this string and translate it to pythonic syntax, then we can use eval
    #will then use the eval function to get derivative
    return (f(x + h) - f(x)) / (h)

def getUserInputsAndParse():
    #func = input("What is the function? (E.g x^2 + 5x + 4)")
    x = 2
    func = "x^2 + 5x + 4"

    print(func)
    math_functions = {
        "sin": "math.sin",
        "cos": "math.cos",
        "tan": "math.tan",
        "log": "math.log",
        "exp": "math.exp",
        "sqrt": "math.sqrt",
        "pi": "math.pi",
        "e": "math.e",
        "^": "**"
    }

    for original, replacement in math_functions.items():
        func = func.replace(original, replacement)
        print(func)

    func = sub(r'(\d)(x)', r'(\1 * \2)', func)
     
    print(func)
    print(eval(func))

    return lambda x: eval(func, {"math": math, "x": x}), x

func, x = getUserInputsAndParse()
print(type(func))
derivative(func, x)

# %% [markdown]
# Nice The bug is gone. Now to get the x value and equation via a input from the user and to add a nicer set of print statements.

# %%
import math
from re import sub

def derivative(f, x, h=0.00001):
    #f = function x = the point we are interested in
    # will need to ask for a function to input
    #will then need to parse this string and translate it to pythonic syntax, then we can use eval
    #will then use the eval function to get derivative
    return (f(x + h) - f(x)) / (h)

def getUserInputsAndParse():
    func = input("What is the function? (E.g x^2 + 5x + 4)") # sin(x)+cos(x^2 )+tan(sqrt(x))+log(x+1)+e^x+ (pi*x^3)  +  sqrt(x^2  +5x+x^5) x =2 --> 69.13283923708491
    x = int(input("What value of x? "))
    print(f"You Have given the equation {func}, And want approximate the derivative at {x}")

    math_functions = {
        "sin": "math.sin",
        "cos": "math.cos",
        "tan": "math.tan",
        "log": "math.log",
        "exp": "math.exp",
        "sqrt": "math.sqrt",
        "pi": "math.pi",
        "e": "math.e",
        "^": "**"
    }

    for original, replacement in math_functions.items():
        func = func.replace(original, replacement)

    func = sub(r'(\d)(x)', r'(\1 * \2)', func)
    return lambda x: eval(func, {"math": math, "x": x}), x

func, x = getUserInputsAndParse()
print(f"""The derivative at x = {x} is approximately:
                                {derivative(func, x)}""")

# %% [markdown]
# Since The assingment only wanted some basic equations like sin(x) or x^2, There may be some areas where this script comes undone so lets give some example functions for the user.

# %%
import math
from re import sub

def derivative(f, x, h=0.00001):
    #f = function x = the point we are interested in
    # will need to ask for a function to input
    #will then need to parse this string and translate it to pythonic syntax, then we can use eval
    #will then use the eval function to get derivative
    return (f(x + h) - f(x)) / (h)

def getUserInputsAndParse():
    example = input("Would you like to see some example functions? [Y/N]")
    while example != "Y" and example != "N":
            example = input("Please use Either Y or N (capitals and only Y or N)")
    else:
         pass
    
    if example == "Y":
        print("""Equation 1:   x^2
Equation 2:   sin(x)
Equation 3:  sin(x) + 10x
Equation 4:  x^2 + 5x + 4
Equation 5:  x^3 + 1 + sin(x^2) + (pi / x^10 ) + x**4 * cos(x)
                        """)
        func = input("What is the function you'd like to calculate the derivative for? (feel free to copy paste from the examples!)")
    elif example == "N":
        func = input("What is the function you'd like to calculate the derivative for? (E.g x^2 + 5x + 4)")

    x = int(input("What value of x? "))
    print(f"You Have given the equation {func}, And want approximate the derivative at {x}")

    math_functions = {
        "sin": "math.sin",
        "cos": "math.cos",
        "tan": "math.tan",
        "log": "math.log",
        "exp": "math.exp",
        "sqrt": "math.sqrt",
        "pi": "math.pi",
        "e": "math.e",
        "^": "**"
    }

    for original, replacement in math_functions.items():
        func = func.replace(original, replacement)

    func = sub(r'(\d)(x)', r'(\1 * \2)', func)
    return lambda x: eval(func, {"math": math, "x": x}), x

func, x = getUserInputsAndParse()
print(f"""The derivative at x = {x} is approximately:
                                {derivative(func, x)}""")
# Out:
# You Have given the equation 1 / (x+1), And want approximate the derivative at -1
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[103], line 52
#      48     return lambda x: eval(func, {"math": math, "x": x}), x
#      50 func, x = getUserInputsAndParse()
#      51 print(f"""The derivative at x = {x} is approximately:
# ---> 52                                 {derivative(func, x)}""")
#
# Cell In[103], line 9, in derivative(f, x, h)
#       4 def derivative(f, x, h=0.00001):
#       5     #f = function x = the point we are interested in
#       6     # will need to ask for a function to input
#       7     #will then need to parse this string and translate it to pythonic syntax, then we can use eval
#       8     #will then use the eval function to get derivative
# ----> 9     return (f(x + h) - f(x)) / (h)
#
# ...

# %% [markdown]
# Looks good to me, The script will allow the user to either copy paste from a list of equations or input their own, Theres one more big issue to resolve while I am here however and that is divide by 0 errors. e.g 1 / (x+1) will give an error at x = -1 so lets catch this and use it to our advantage

# %%
import math
from re import sub

def derivative(f, x, h=0.00001):
    #f = function x = the point we are interested in
    # will need to ask for a function to input
    #will then need to parse this string and translate it to pythonic syntax, then we can use eval
    #will then use the eval function to get derivative
    try:
        return (f(x + h) - f(x)) / h
    except ZeroDivisionError:
        return None

def getUserInputsAndParse():
    example = input("Would you like to see some example functions? [Y/N]")
    while example != "Y" and example != "N":
            example = input("Please use Either Y or N (capitals and only Y or N)")
    else:
         pass
    
    if example == "Y":
        print("""Equation 1:   x^2
Equation 2:   sin(x)
Equation 3:  sin(x) + 10x
Equation 4:  x^2 + 5x + 4
Equation 5:  x^3 + 1 + sin(x^2) + (pi / x^10 ) + x**4 * cos(x)
Equation 6 : 1 / (x + 1)
                        """)
        func = input("What is the function you'd like to calculate the derivative for? (feel free to copy paste from the examples!)")
    elif example == "N":
        func = input("What is the function you'd like to calculate the derivative for? (E.g x^2 + 5x + 4)")

    x = int(input("What value of x? "))

    print(f"You Have given the equation {func}, And want approximate the derivative at {x}")

    math_functions = {
        "sin": "math.sin",
        "cos": "math.cos",
        "tan": "math.tan",
        "log": "math.log",
        "exp": "math.exp",
        "sqrt": "math.sqrt",
        "pi": "math.pi",
        "e": "math.e",
        "^": "**"
    }

    for original, replacement in math_functions.items():
        func = func.replace(original, replacement)

    func = sub(r'(\d)(x)', r'(\1 * \2)', func)
    return lambda x: eval(func, {"math": math, "x": x}), x

func, x = getUserInputsAndParse()
derivative_result = derivative(func, x)
if derivative_result is None:
    print(f"The derivative at x = {x} is undefined.")
else:
    print(f"""The derivative at x = {x} is approximately:
                                {derivative_result}""")
# Out:
# Equation 1:   x^2
# Equation 2:   sin(x)
# Equation 3:  sin(x) + 10x
# Equation 4:  x^2 + 5x + 4
# Equation 5:  x^3 + 1 + sin(x^2) + (pi / x^10 ) + x**4 * cos(x)
# Equation 6 : 1 / (x + 1)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[106], line 55
#      52     func = sub(r'(\d)(x)', r'(\1 * \2)', func)
#      53     return lambda x: eval(func, {"math": math, "x": x}), x
# ---> 55 func, x = getUserInputsAndParse()
#      56 derivative_result = derivative(func, x)
#      57 if derivative_result is None:
#
# Cell In[106], line 33, in getUserInputsAndParse()
#      30 elif example == "N":
#      31     func = input("What is the function you'd like to calculate the derivative for? (E.g x^2 + 5x + 4)")
# ---> 33 x = int(input("What value of x? "))
#      35 print(f"You Have given the equation {func}, And want approximate the derivative at {x}")
# ...

# %% [markdown]
# We are almost there, now i see a bug where it wont print the example functions but will ask for an input, to avoid this lets import time.sleep and time the script out for 0.1 between

# %%
import math
from re import sub
from time import sleep

def derivative(f, x, h=0.00001):
    #f = function x = the point we are interested in
    # will need to ask for a function to input
    #will then need to parse this string and translate it to pythonic syntax, then we can use eval
    #will then use the eval function to get derivative
    try:
        return (f(x + h) - f(x)) / h
    except ZeroDivisionError:
        return None

def getUserInputsAndParse():
    example = input("Would you like to see some example functions? [Y/N]")
    while example != "Y" and example != "N":
            example = input("Please use Either Y or N (capitals and only Y or N)")
    else:
         pass
    
    if example == "Y":
        print("""Equation 1:   x^2
Equation 2:   sin(x)
Equation 3:  sin(x) + 10x
Equation 4:  x^2 + 5x + 4
Equation 5:  x^3 + 1 + sin(x^2) + (pi / x^10 ) + x**4 * cos(x)
Equation 6 : 1 / (x + 1)
                        """)
        sleep(0.1)
        func = input("What is the function you'd like to calculate the derivative for? (feel free to copy paste from the examples!)")
    elif example == "N":
        func = input("What is the function you'd like to calculate the derivative for? (E.g x^2 + 5x + 4)")

    x = int(input("What value of x? "))

    print(f"You Have given the equation {func}, And want approximate the derivative at {x}")

    math_functions = {
        "sin": "math.sin",
        "cos": "math.cos",
        "tan": "math.tan",
        "log": "math.log",
        "exp": "math.exp",
        "sqrt": "math.sqrt",
        "pi": "math.pi",
        "e": "math.e",
        "^": "**"
    }

    for original, replacement in math_functions.items():
        func = func.replace(original, replacement)

    func = sub(r'(\d)(x)', r'(\1 * \2)', func)
    return lambda x: eval(func, {"math": math, "x": x}), x

func, x = getUserInputsAndParse()
derivative_result = derivative(func, x)
if derivative_result is None:
    print(f"The derivative at x = {x} is undefined.")
else:
    print(f"""The derivative at x = {x} is approximately:
                                {derivative_result}""")
# Out:
# Equation 1:   x^2
# Equation 2:   sin(x)
# Equation 3:  sin(x) + 10x
# Equation 4:  x^2 + 5x + 4
# Equation 5:  x^3 + 1 + sin(x^2) + (pi / x^10 ) + x**4 * cos(x)
# Equation 6 : 1 / (x + 1)
#
# You Have given the equation 1 / (x + 1), And want approximate the derivative at -1
# The derivative at x = -1 is undefined.

# %% [markdown]
# Amazing, I am Happy with where this is. I shall now move onto the Extension.

# %% [markdown]
# 3. Extension:
#
# Modify the function to use the centred difference method for more
# accurate results:
#
# 𝑓′(𝑥)≅(𝑓(𝑥 + ℎ ) - 𝑓(𝑥 - h)) / 2ℎ

# %% [markdown]
# This is really easy to implement in our script we only need to edit 1 line of code.

# %%
import math
from re import sub
from time import sleep

def derivative(f, x, h=0.00001):
    try:
        return (f(x + h) - f(x - h)) / (2 * h)
    except ZeroDivisionError:
        return None

def getUserInputsAndParse():
    example = input("Would you like to see some example functions? [Y/N]")
    while example != "Y" and example != "N":
            example = input("Please use Either Y or N (capitals and only Y or N)")
    else:
         pass
    
    if example == "Y":
        print("""Equation 1:   x^2
Equation 2:   sin(x)
Equation 3:  sin(x) + 10x
Equation 4:  x^2 + 5x + 4
Equation 5:  x^3 + 1 + sin(x^2) + (pi / x^10 ) + x**4 * cos(x)
Equation 6 : 1 / (x + 1)
                        """)
        sleep(0.1)
        func = input("What is the function you'd like to calculate the derivative for? (feel free to copy paste from the examples!)")
    elif example == "N":
        func = input("What is the function you'd like to calculate the derivative for? (E.g x^2 + 5x + 4)")

    x = int(input("What value of x? "))

    print(f"You Have given the equation {func}, And want approximate the derivative at {x}")

    math_functions = {
        "sin": "math.sin",
        "cos": "math.cos",
        "tan": "math.tan",
        "log": "math.log",
        "exp": "math.exp",
        "sqrt": "math.sqrt",
        "pi": "math.pi",
        "e": "math.e",
        "^": "**"
    }

    for original, replacement in math_functions.items():
        func = func.replace(original, replacement)

    func = sub(r'(\d)(x)', r'(\1 * \2)', func)
    return lambda x: eval(func, {"math": math, "x": x}), x

func, x = getUserInputsAndParse()
derivative_result = derivative(func, x)
if derivative_result is None:
    print(f"The derivative at x = {x} is undefined.")
else:
    print(f"""The derivative at x = {x} is approximately:
                                {derivative_result}""")

# %% [markdown]
# Looks good to me. There are some bugs that may occur, but most of this are common bugs within the casio calculators and will resolve around more parsing for brackets. since calculators are a common tool I shall neglect for any further parsing as it may cause user confusion, and people should be comfortable using calculator syntax within this script.
